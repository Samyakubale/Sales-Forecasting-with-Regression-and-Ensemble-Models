# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings('ignore')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
display (os.getcwd())
# Out:
# 'C:\\Users\\Sanch'

# %%
os.chdir ('C:\\Users\\Sanch\\OneDrive\\Documents\\Acmegrade\\PROJECT\\SALES FORECASTING\\')
display (os.getcwd())
# Out:
# 'C:\\Users\\Sanch\\OneDrive\\Documents\\Acmegrade\\PROJECT\\SALES FORECASTING'

# %%
dt = pd.read_csv('Train.csv')
display (dt.head())
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
print (dt.shape)
# Out:
# (8523, 12)

# %%
display (dt.columns)
display (dt.describe())
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
display (dt.info())
display (dt.apply(lambda x: len(x.unique())))
display (dt.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB
# None
# Item_Identifier              1559
# Item_Weight                   416
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     4
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
top_100 =  dt.head (100)
def highlight_null(val):
    color = 'yellow' if pd.isnull(val) else ''
    return 'background-color: %s' % color
    
color_null = top_100.style.applymap(highlight_null)

display (color_null)
# Out:
# <style type="text/css">
# #T_be3ee_row0_col0, #T_be3ee_row0_col1, #T_be3ee_row0_col2, #T_be3ee_row0_col3, #T_be3ee_row0_col4, #T_be3ee_row0_col5, #T_be3ee_row0_col6, #T_be3ee_row0_col7, #T_be3ee_row0_col8, #T_be3ee_row0_col9, #T_be3ee_row0_col10, #T_be3ee_row0_col11, #T_be3ee_row1_col0, #T_be3ee_row1_col1, #T_be3ee_row1_col2, #T_be3ee_row1_col3, #T_be3ee_row1_col4, #T_be3ee_row1_col5, #T_be3ee_row1_col6, #T_be3ee_row1_col7, #T_be3ee_row1_col8, #T_be3ee_row1_col9, #T_be3ee_row1_col10, #T_be3ee_row1_col11, #T_be3ee_row2_col0, #T_be3ee_row2_col1, #T_be3ee_row2_col2, #T_be3ee_row2_col3, #T_be3ee_row2_col4, #T_be3ee_row2_col5, #T_be3ee_row2_col6, #T_be3ee_row2_col7, #T_be3ee_row2_col8, #T_be3ee_row2_col9, #T_be3ee_row2_col10, #T_be3ee_row2_col11, #T_be3ee_row3_col0, #T_be3ee_row3_col1, #T_be3ee_row3_col2, #T_be3ee_row3_col3, #T_be3ee_row3_col4, #T_be3ee_row3_col5, #T_be3ee_row3_col6, #T_be3ee_row3_col7, #T_be3ee_row3_col9, #T_be3ee_row3_col10, #T_be3ee_row3_col11, #T_be3ee_row4_col0, #T_be3ee_row4_col1, #T_be3ee_row4_col2, #T_be3ee_row4_col3, #T_be3ee_row4_col4, #T_be3ee_row4_col5, #T_be3ee_row4_col6, #T_be3ee_row4_col7, #T_be3ee_row4_col8, #T_be3ee_row4_col9, #T_be3ee_row4_col10, #T_be3ee_row4_col11, #T_be3ee_row5_col0, #T_be3ee_row5_col1, #T_be3ee_row5_col2, #T_be3ee_row5_col3, #T_be3ee_row5_col4, #T_be3ee_row5_col5, #T_be3ee_row5_col6, #T_be3ee_row5_col7, #T_be3ee_row5_col8, #T_be3ee_row5_col9, #T_be3ee_row5_col10, #T_be3ee_row5_col11, #T_be3ee_row6_col0, #T_be3ee_row6_col1, #T_be3ee_row6_col2, #T_be3ee_row6_col3, #T_be3ee_row6_col4, #T_be3ee_row6_col5, #T_be3ee_row6_col6, #T_be3ee_row6_col7, #T_be3ee_row6_col8, #T_be3ee_row6_col9, #T_be3ee_row6_col10, #T_be3ee_row6_col11, #T_be3ee_row7_col0, #T_be3ee_row7_col2, #T_be3ee_row7_col3, #T_be3ee_row7_col4, #T_be3ee_row7_col5, #T_be3ee_row7_col6, #T_be3ee_row7_col7, #T_be3ee_row7_col8, #T_be3ee_row7_col9, #T_be3ee_row7_col10, #T_be3ee_row7_col11, #T_be3ee_row8_col0, #T_be3ee_row8_col1, #T_be3ee_row8_col2, #T_be3ee_row8_col3, #T_be3ee_row8_col4, #T_be3ee_row8_col5, #T_be3ee_row8_col6, #T_be3ee_row8_col7, #T_be3ee_row8_col9, #T_be3ee_row8_col10, #T_be3ee_row8_col11, #T_be3ee_row9_col0, #T_be3ee_row9_col1, #T_be3ee_row9_col2, #T_be3ee_row9_col3, #T_be3ee_row9_col4, #T_be3ee_row9_col5, #T_be3ee_row9_col6, #T_be3ee_row9_col7, #T_be3ee_row9_col9, #T_be3ee_row9_col10, #T_be3ee_row9_col11, #T_be3ee_row10_col0, #T_be3ee_row10_col1, #T_be3ee_row10_col2, #T_be3ee_row10_col3, #T_be3ee_row10_col4, #T_be3ee_row10_col5, #T_be3ee_row10_col6, #T_be3ee_row10_col7, #T_be3ee_row10_col8, #T_be3ee_row10_col9, #T_be3ee_row10_col10, #T_be3ee_row10_col11, #T_be3ee_row11_col0, #T_be3ee_row11_col1, #T_be3ee_row11_col2, #T_be3ee_row11_col3, #T_be3ee_row11_col4, #T_be3ee_row11_col5, #T_be3ee_row11_col6, #T_be3ee_row11_col7, #T_be3ee_row11_col8, #T_be3ee_row11_col9, #T_be3ee_row11_col10, #T_be3ee_row11_col11, #T_be3ee_row12_col0, #T_be3ee_row12_col1, #T_be3ee_row12_col2, #T_be3ee_row12_col3, #T_be3ee_row12_col4, #T_be3ee_row12_col5, #T_be3ee_row12_col6, #T_be3ee_row12_col7, #T_be3ee_row12_col8, #T_be3ee_row12_col9, #T_be3ee_row12_col10, #T_be3ee_row12_col11, #T_be3ee_row13_col0, #T_be3ee_row13_col1, #T_be3ee_row13_col2, #T_be3ee_row13_col3, #T_be3ee_row13_col4, #T_be3ee_row13_col5, #T_be3ee_row13_col6, #T_be3ee_row13_col7, #T_be3ee_row13_col8, #T_be3ee_row13_col9, #T_be3ee_row13_col10, #T_be3ee_row13_col11, #T_be3ee_row14_col0, #T_be3ee_row14_col1, #T_be3ee_row14_col2, #T_be3ee_row14_col3, #T_be3ee_row14_col4, #T_be3ee_row14_col5, #T_be3ee_row14_col6, #T_be3ee_row14_col7, #T_be3ee_row14_col8, #T_be3ee_row14_col9, #T_be3ee_row14_col10, #T_be3ee_row14_col11, #T_be3ee_row15_col0, #T_be3ee_row15_col1, #T_be3ee_row15_col2, #T_be3ee_row15_col3, #T_be3ee_row15_col4, #T_be3ee_row15_col5, #T_be3ee_row15_col6, #T_be3ee_row15_col7, #T_be3ee_row15_col8, #T_be3ee_row15_col9, #T_be3ee_row15_col10, #T_be3ee_row15_col11, #T_be3ee_row16_col0, #T_be3ee_row16_col1, #T_be3ee_row16_col2, #T_be3ee_row16_col3, #T_be3ee_row16_col4, #T_be3ee_row16_col5, #T_be3ee_r ...

# %%
cat_col = []
for x in dt.dtypes.index:
    if dt.dtypes[x] == 'object':
        cat_col.append(x)
display (cat_col)
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
cat_col.remove('Item_Identifier')
cat_col.remove('Outlet_Identifier')
display (cat_col)
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
for col in cat_col:
    print(col , len(dt[col].unique()))
# Out:
# Item_Fat_Content 5
# Item_Type 16
# Outlet_Size 4
# Outlet_Location_Type 3
# Outlet_Type 4

# %%
for col in cat_col:
    print(col)
    print(dt[col].value_counts())
    print()
    print ('*' *50)
# Out:
# Item_Fat_Content
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64
#
# **************************************************
# Item_Type
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64
#
# **************************************************
# Outlet_Size
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64
#
# **************************************************
# Outlet_Location_Type
# Outlet_Location_Type
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: count, dtype: int64
#
# **************************************************
# Outlet_Type
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64
#
# **************************************************

# %%
miss_bool = dt['Item_Weight'].isnull()
display (miss_bool)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Weight, Length: 8523, dtype: bool

# %%
display (dt['Item_Weight'].isnull().sum())
# Out:
# np.int64(1463)

# %%
Item_Weight_null = dt[dt['Item_Weight'].isna()]
display (Item_Weight_null)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# 18              Hard Drinks  113.2834            OUT027
# 21             Baking Goods  144.5444            OUT027
# 23             Baking Goods  107.6938            OUT019
# 29                   Canned   43.6454            OUT019
# ...                     ...       ...               ...
# 8485            Soft Drinks  189.0530            OUT027
# 8487            Soft Drinks  164.7526            OUT027
# 8488                 Others  184.6608            OUT027
# 8490  Fruits and Vegetables  162.3552            OUT019
# 8504              Household  111.7544            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7                          1985      Medium               Tier 3
# 18                         1985      Medium               Tier 3
# 21                         1985      Medium               Tier 3
# 23                         1985       Small               Tier 1
# 29                         1985       Small               Tier 1
# ...                         ...         ...                  ...
# 8485                       1985      Medium               Tier 3
# 8487                       1985      Medium               Tier 3
# 8488                       1985      Medium               Tier 3
# 8490                       1985       Small               Tier 1
# 8504                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 7     Supermarket Type3          4022.7636
# 18    Supermarket Type3          2303.6680
# 21    Supermarket Type3          4064.0432
# 23        Grocery Store           214.3876
# 29        Grocery Store           125.8362
# ...                 ...                ...
# 8485  Supermarket Type3          6261.8490
# 8487  Supermarket Type3          4111.3150
# 8488  Supermarket Type3          2756.4120
# 8490      Grocery Store           487.3656
# 8504  Supermarket Type3          4138.6128
#
# [1463 rows x 12 columns]

# %%
Item_Weight_null['Item_Identifier'].value_counts()
# Out:
# Item_Identifier
# FDS02    2
# FDI26    2
# FDT09    2
# FDL52    2
# FDT46    2
#         ..
# FDR04    1
# FDL43    1
# FDX60    1
# NCP17    1
# FDB34    1
# Name: count, Length: 1142, dtype: int64

# %%
item_weight_mean = dt.pivot_table(values = "Item_Weight", index = 'Item_Identifier')
display (item_weight_mean)
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]

# %%
display (dt['Item_Identifier'])
# Out:
# 0       FDA15
# 1       DRC01
# 2       FDN15
# 3       FDX07
# 4       NCD19
#         ...
# 8518    FDF22
# 8519    FDS36
# 8520    NCJ29
# 8521    FDN46
# 8522    DRG01
# Name: Item_Identifier, Length: 8523, dtype: object

# %%
for i, item in enumerate(dt['Item_Identifier']):
    if miss_bool[i]:
        if item in item_weight_mean.index:
            dt['Item_Weight'][i] = item_weight_mean.loc[item]['Item_Weight']
        else:
            dt['Item_Weight'][i] = np.mean(dt['Item_Weight'])

# %%
result = dt['Item_Weight'].isnull().sum()
display (result)
# Out:
# np.int64(0)

# %%
result = dt.groupby('Outlet_Size').agg({'Outlet_Size': np.size})
display (result)
# Out:
#              Outlet_Size
# Outlet_Size
# High                 932
# Medium              2793
# Small               2388

# %%
result= dt['Outlet_Size'].isnull().sum()
display (result)
# Out:
# np.int64(2410)

# %%
Outlet_Size_null= dt[dt['Outlet_Size'].isna()]
display (Outlet_Size_null)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# 8              Frozen Foods   96.9726            OUT045
# 9              Frozen Foods  187.8214            OUT017
# 25                Household   45.9060            OUT017
# 28                    Dairy   45.5086            OUT010
# ...                     ...       ...               ...
# 8502              Household  216.4192            OUT045
# 8508  Fruits and Vegetables  199.4742            OUT045
# 8509  Fruits and Vegetables  213.9902            OUT010
# 8514                 Canned   57.5904            OUT045
# 8519           Baking Goods  108.1570            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3                          1998         NaN               Tier 3
# 8                          2002         NaN               Tier 2
# 9                          2007         NaN               Tier 2
# 25                         2007         NaN               Tier 2
# 28                         1998         NaN               Tier 3
# ...                         ...         ...                  ...
# 8502                       2002         NaN               Tier 2
# 8508                       2002         NaN               Tier 2
# 8509                       1998         NaN               Tier 3
# 8514                       2002         NaN               Tier 2
# 8519                       2002         NaN               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 3         Grocery Store           732.3800
# 8     Supermarket Type1          1076.5986
# 9     Supermarket Type1          4710.5350
# 25    Supermarket Type1           838.9080
# 28        Grocery Store           178.4344
# ...                 ...                ...
# 8502  Supermarket Type1          3020.0688
# 8508  Supermarket Type1          2587.9646
# 8509      Grocery Store           424.7804
# 8514  Supermarket Type1           468.7232
# 8519  Supermarket Type1           549.2850
#
# [2410 rows x 12 columns]

# %%
result = Outlet_Size_null['Outlet_Type'].value_counts()
display (result)
# Out:
# Outlet_Type
# Supermarket Type1    1855
# Grocery Store         555
# Name: count, dtype: int64

# %%
result= dt.groupby (['Outlet_Type','Outlet_Size'] ).agg({'Outlet_Type':[np.size]})
display (result)
# Out:
#                               Outlet_Type
#                                      size
# Outlet_Type       Outlet_Size
# Grocery Store     Small               528
# Supermarket Type1 High                932
#                   Medium              930
#                   Small              1860
# Supermarket Type2 Medium              928
# Supermarket Type3 Medium              935

# %%
outlet_size_mode = dt.pivot_table(values='Outlet_Size', columns='Outlet_Type', aggfunc=(lambda x: x.mode()[0]))
display (outlet_size_mode)
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
miss_bool = dt['Outlet_Size'].isnull()
dt.loc[miss_bool, 'Outlet_Size'] = dt.loc[miss_bool, 'Outlet_Type'].apply(lambda x: outlet_size_mode[x])

# %%
miss_bool = dt['Outlet_Size'].isnull()
for i, item in enumerate (dt['Outlet_Size']):
    if miss_bool[i]:
        dt['Outlet_Size'][i] = outlet_size_mode.loc['Outlet_Size',dt['Outlet_Type'][i] ]

# %%
display (dt['Outlet_Size'].isnull().sum())
# Out:
# np.int64(0)

# %%
result = dt.groupby (['Outlet_Type','Outlet_Size'] ).agg({'Outlet_Type':["size"]})
display (result)
# Out:
#                               Outlet_Type
#                                      size
# Outlet_Type       Outlet_Size
# Grocery Store     Small              1083
# Supermarket Type1 High                932
#                   Medium              930
#                   Small              3715
# Supermarket Type2 Medium              928
# Supermarket Type3 Medium              935

# %%
display (sum(dt['Item_Visibility']==0))
# Out:
# 526

# %%
dt.loc[:, 'Item_Visibility'].replace([0], [dt['Item_Visibility'].mean()], inplace=True)

# %%
display(sum(dt['Item_Visibility']==0))
# Out:
# 0

# %%
result = dt['Item_Fat_Content'].value_counts()
display (result)
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
dt['Item_Fat_Content'] = dt['Item_Fat_Content'].replace({'LF':'Low Fat', 'reg':'Regular', 'low fat':'Low Fat'})
result = dt['Item_Fat_Content'].value_counts()
display (result)
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
dt['New_Item_Type'] = dt['Item_Identifier'].apply(lambda x: x[:2])
display (dt['New_Item_Type'])
# Out:
# 0       FD
# 1       DR
# 2       FD
# 3       FD
# 4       NC
#         ..
# 8518    FD
# 8519    FD
# 8520    NC
# 8521    FD
# 8522    DR
# Name: New_Item_Type, Length: 8523, dtype: object

# %%
display (dt['New_Item_Type'].value_counts())
# Out:
# New_Item_Type
# FD    6125
# NC    1599
# DR     799
# Name: count, dtype: int64

# %%
dt['New_Item_Type'] = dt['New_Item_Type'].map({'FD':'Food', 'NC':'Non-Consumable', 'DR':'Drinks'})
display (dt['New_Item_Type'].value_counts())
# Out:
# New_Item_Type
# Food              6125
# Non-Consumable    1599
# Drinks             799
# Name: count, dtype: int64

# %%
display (dt['Item_Fat_Content'].value_counts())
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
result = dt.groupby (['New_Item_Type','Item_Fat_Content'] ).agg({'Outlet_Type':[np.size]})
display (result)
# Out:
#                                 Outlet_Type
#                                        size
# New_Item_Type  Item_Fat_Content
# Drinks         Low Fat                  728
#                Regular                   71
# Food           Low Fat                 3190
#                Regular                 2935
# Non-Consumable Low Fat                 1599

# %%
dt.loc[dt['New_Item_Type']=='Non-Consumable', 'Item_Fat_Content'] = 'Non-Edible'
result =  (dt['Item_Fat_Content'].value_counts())
display (result)
# Out:
# Item_Fat_Content
# Low Fat       3918
# Regular       3006
# Non-Edible    1599
# Name: count, dtype: int64

# %%
result = dt.groupby (['New_Item_Type','Item_Fat_Content'] ).agg({'Outlet_Type':[np.size]})
display (result)
# Out:
#                                 Outlet_Type
#                                        size
# New_Item_Type  Item_Fat_Content
# Drinks         Low Fat                  728
#                Regular                   71
# Food           Low Fat                 3190
#                Regular                 2935
# Non-Consumable Non-Edible              1599

# %%
dt['Outlet_Years'] = 2024 - dt['Outlet_Establishment_Year']
print (dt['Outlet_Years'])
# Out:
# 0       25
# 1       15
# 2       25
# 3       26
# 4       37
#         ..
# 8518    37
# 8519    22
# 8520    20
# 8521    15
# 8522    27
# Name: Outlet_Years, Length: 8523, dtype: int64

# %%
display (dt.head())
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.066132
# 4           NCD19         8.93       Non-Edible         0.066132
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales   New_Item_Type  Outlet_Years
# 0  Supermarket Type1          3735.1380            Food            25
# 1  Supermarket Type2           443.4228          Drinks            15
# 2  Supermarket Type1          2097.2700            Food            25
# 3      Grocery Store           732.3800            Food            26
# 4  Supermarket Type1           994.7052  Non-Consumable            37

# %%
sns.distplot(dt['Item_Weight'])
plt.show()

# %%
sns.distplot(dt['Item_Visibility'])
plt.show()

# %%
sns.distplot(dt['Item_MRP'])
plt.show()

# %%
sns.distplot(dt['Item_Outlet_Sales'])
plt.show()

# %%
# The above dist plot is right skewed, there might be outliers in the right side. To reduce the outliers, implement log transformation 
dt['Item_Outlet_Sales'] = np.log(1+dt['Item_Outlet_Sales'])
display (dt['Item_Outlet_Sales'])
# Out:
# 0       8.225808
# 1       6.096776
# 2       7.648868
# 3       6.597664
# 4       6.903451
#           ...
# 8518    7.929984
# 8519    6.310436
# 8520    7.085159
# 8521    7.521100
# 8522    6.642056
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
sns.distplot(dt['Item_Outlet_Sales'])
plt.show()

# %%
sns.countplot(x = dt["Item_Fat_Content"])
plt.show()

# %%
# l is the list of unique Item Types - This is used to display X-Label 
l = list(dt['Item_Type'].unique()) 
chart = sns.countplot(x =dt["Item_Type"])
chart.set_xticklabels(labels=l, rotation=90)
plt.show()

# %%
#Number of stores started per year  
sns.countplot(x= dt['Outlet_Establishment_Year'])
plt.show()

# %%
sns.countplot(x=dt['Outlet_Size'])
plt.show()

# %%
sns.countplot(x=dt['Outlet_Location_Type'])
plt.show()

# %%
sns.countplot(x= dt['Outlet_Type'])
plt.show()

# %%
display(dt.head(3))
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
# 2           FDN15        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales New_Item_Type  \
# 0               Tier 1  Supermarket Type1           8.225808          Food
# 1               Tier 3  Supermarket Type2           6.096776        Drinks
# 2               Tier 1  Supermarket Type1           7.648868          Food
#
#    Outlet_Years
# 0            25
# 1            15
# 2            25

# %%
dtc= dt.iloc[:,[1,3,5,7,11,13]]
display (dtc)
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.066132  182.0950                       1998
# 4           8.930         0.066132   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales  Outlet_Years
# 0              8.225808            25
# 1              6.096776            15
# 2              7.648868            25
# 3              6.597664            26
# 4              6.903451            37
# ...                 ...           ...
# 8518           7.929984            37
# 8519           6.310436            22
# 8520           7.085159            20
# 8521           7.521100            15
# 8522           6.642056            27
#
# [8523 rows x 6 columns]

# %%
corr = dtc.corr()
display (corr)
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.017477  0.025972
# Item_Visibility              -0.017477         1.000000 -0.005259
# Item_MRP                      0.025972        -0.005259  1.000000
# Outlet_Establishment_Year    -0.013418        -0.078355  0.005020
# Item_Outlet_Sales             0.007675        -0.202466  0.509886
# Outlet_Years                  0.013418         0.078355 -0.005020
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales  \
# Item_Weight                                -0.013418           0.007675
# Item_Visibility                            -0.078355          -0.202466
# Item_MRP                                    0.005020           0.509886
# Outlet_Establishment_Year                   1.000000           0.077032
# Item_Outlet_Sales                           0.077032           1.000000
# Outlet_Years                               -1.000000          -0.077032
#
#                            Outlet_Years
# Item_Weight                    0.013418
# Item_Visibility                0.078355
# Item_MRP                      -0.005020
# Outlet_Establishment_Year     -1.000000
# Item_Outlet_Sales             -0.077032
# Outlet_Years                   1.000000

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
display (dt.head())
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.066132
# 4           NCD19         8.93       Non-Edible         0.066132
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales   New_Item_Type  Outlet_Years
# 0  Supermarket Type1           8.225808            Food            25
# 1  Supermarket Type2           6.096776          Drinks            15
# 2  Supermarket Type1           7.648868            Food            25
# 3      Grocery Store           6.597664            Food            26
# 4  Supermarket Type1           6.903451  Non-Consumable            37

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dt['Outlet'] = le.fit_transform(dt['Outlet_Identifier'])
display (dt['Outlet'])
# Out:
# 0       9
# 1       3
# 2       9
# 3       0
# 4       1
#        ..
# 8518    1
# 8519    7
# 8520    6
# 8521    3
# 8522    8
# Name: Outlet, Length: 8523, dtype: int64

# %%
cat_col = ['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'New_Item_Type']
for col in cat_col:
    dt[col] = le.fit_transform(dt[col])
display (dt.head())
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15         9.30                 0         0.016047          4
# 1           DRC01         5.92                 2         0.019278         14
# 2           FDN15        17.50                 0         0.016760         10
# 3           FDX07        19.20                 2         0.066132          6
# 4           NCD19         8.93                 1         0.066132          9
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092            OUT049                       1999            1
# 1   48.2692            OUT018                       2009            1
# 2  141.6180            OUT049                       1999            1
# 3  182.0950            OUT010                       1998            2
# 4   53.8614            OUT013                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  New_Item_Type  \
# 0                     0            1           8.225808              1
# 1                     2            2           6.096776              0
# 2                     0            1           7.648868              1
# 3                     2            0           6.597664              1
# 4                     2            1           6.903451              2
#
#    Outlet_Years  Outlet
# 0            25       9
# 1            15       3
# 2            25       9
# 3            26       0
# 4            37       1

# %%
dt = pd.get_dummies(dt, columns=['Item_Fat_Content', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'New_Item_Type'],dtype = int )
display (dt.head())
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0           FDA15         9.30         0.016047          4  249.8092
# 1           DRC01         5.92         0.019278         14   48.2692
# 2           FDN15        17.50         0.016760         10  141.6180
# 3           FDX07        19.20         0.066132          6  182.0950
# 4           NCD19         8.93         0.066132          9   53.8614
#
#   Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales  \
# 0            OUT049                       1999           8.225808
# 1            OUT018                       2009           6.096776
# 2            OUT049                       1999           7.648868
# 3            OUT010                       1998           6.597664
# 4            OUT013                       1987           6.903451
#
#    Outlet_Years  Outlet  ...  Outlet_Location_Type_0  Outlet_Location_Type_1  \
# 0            25       9  ...                       1                       0
# 1            15       3  ...                       0                       0
# 2            25       9  ...                       1                       0
# 3            26       0  ...                       0                       0
# 4            37       1  ...                       0                       0
#
#    Outlet_Location_Type_2  Outlet_Type_0  Outlet_Type_1  Outlet_Type_2  \
# 0                       0              0              1              0
# 1                       1              0              0              1
# 2                       0              0              1              0
# 3                       1              1              0              0
# 4                       1              0              1              0
#
#    Outlet_Type_3  New_Item_Type_0  New_Item_Type_1  New_Item_Type_2
# 0              0                0                1                0
# 1              0                1                0                0
# 2              0                0                1                0
# 3              0                0                1                0
# 4              0                0                0                1
#
# [5 rows x 26 columns]

# %%
X = dt.drop(columns=['Outlet_Establishment_Year', 'Item_Identifier', 'Outlet_Identifier', 'Item_Outlet_Sales'])
display (X.head())
# Out:
#    Item_Weight  Item_Visibility  Item_Type  Item_MRP  Outlet_Years  Outlet  \
# 0         9.30         0.016047          4  249.8092            25       9
# 1         5.92         0.019278         14   48.2692            15       3
# 2        17.50         0.016760         10  141.6180            25       9
# 3        19.20         0.066132          6  182.0950            26       0
# 4         8.93         0.066132          9   53.8614            37       1
#
#    Item_Fat_Content_0  Item_Fat_Content_1  Item_Fat_Content_2  Outlet_Size_0  \
# 0                   1                   0                   0              0
# 1                   0                   0                   1              0
# 2                   1                   0                   0              0
# 3                   0                   0                   1              0
# 4                   0                   1                   0              1
#
#    ...  Outlet_Location_Type_0  Outlet_Location_Type_1  \
# 0  ...                       1                       0
# 1  ...                       0                       0
# 2  ...                       1                       0
# 3  ...                       0                       0
# 4  ...                       0                       0
#
#    Outlet_Location_Type_2  Outlet_Type_0  Outlet_Type_1  Outlet_Type_2  \
# 0                       0              0              1              0
# 1                       1              0              0              1
# 2                       0              0              1              0
# 3                       1              1              0              0
# 4                       1              0              1              0
#
#    Outlet_Type_3  New_Item_Type_0  New_Item_Type_1  New_Item_Type_2
# 0              0                0                1                0
# 1              0                1                0                0
# 2              0                0                1                0
# 3              0                0                1                0
# 4              0                0                0                1
#
# [5 rows x 22 columns]

# %%
y = dt['Item_Outlet_Sales']
display (y.head())
# Out:
# 0    8.225808
# 1    6.096776
# 2    7.648868
# 3    6.597664
# 4    6.903451
# Name: Item_Outlet_Sales, dtype: float64

# %%
from sklearn import metrics 
display (",   ".join(metrics.get_scorer_names()))
# Out:
# 'accuracy,   adjusted_mutual_info_score,   adjusted_rand_score,   average_precision,   balanced_accuracy,   completeness_score,   d2_absolute_error_score,   explained_variance,   f1,   f1_macro,   f1_micro,   f1_samples,   f1_weighted,   fowlkes_mallows_score,   homogeneity_score,   jaccard,   jaccard_macro,   jaccard_micro,   jaccard_samples,   jaccard_weighted,   matthews_corrcoef,   mutual_info_score,   neg_brier_score,   neg_log_loss,   neg_max_error,   neg_mean_absolute_error,   neg_mean_absolute_percentage_error,   neg_mean_gamma_deviance,   neg_mean_poisson_deviance,   neg_mean_squared_error,   neg_mean_squared_log_error,   neg_median_absolute_error,   neg_negative_likelihood_ratio,   neg_root_mean_squared_error,   neg_root_mean_squared_log_error,   normalized_mutual_info_score,   positive_likelihood_ratio,   precision,   precision_macro,   precision_micro,   precision_samples,   precision_weighted,   r2,   rand_score,   recall,   recall_macro,   recall_micro,   recall_samples,   recall_weighted,   roc_auc,   roc_auc_ovo,   roc_auc_ovo_weighted,   roc_auc_ovr,   roc_auc_ovr_weighted,   top_k_accuracy,   v_measure_score'

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
def train(model, X, y):

    print ("Train Test Split")
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
    print (X.shape, y.shape)
    print (X_train.shape, X_test.shape ,  y_train.shape, y_test.shape)
    
    # training the model
    model.fit(X_train, y_train)       
   
    # perform cross-validation
    cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    print("Model Report")
    print ('Scoring - neg_mean_squared_error')
    print ( cv_score )    
    cv_score = np.abs(np.mean(cv_score))    
    print ('ABS Average of - neg_mean_squared_error',cv_score )       
    cv_score = cross_val_score(model, X, y,  cv=5)
    print ()
    print ('R2 Score ')
    print ( cv_score )    
    cv_score = np.mean(cv_score)     
    print ('Average R2 Score ',cv_score)    
    print ()
    
    # Display Accuracy
    print ('Accuracy')
    print ('Accuracy of Test data')
    y_test_pred = model.predict(X_test)
    print('R2_Score:', r2_score(y_test,y_test_pred))
    print ('Accuracy of Training data')
    y_train_pred = model.predict(X_train)
    print('R2_Score:', r2_score(y_train,y_train_pred))
    print ('Accuracy of Complete data')
    y_pred = model.predict(X)
    print('R2_Score:', r2_score(y,y_pred))
    print ()

    # Display graph with actual and predicted values 
    
    plt.subplot (212)
    print ('Display actual and predicted values')
    sns.regplot( x =y, y= y_pred, scatter_kws={"color": "b"}, 
            line_kws={"color": "r"},ci = None)
    plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
train(model, X,y)
coef = pd.Series(model.coef_, X.columns).sort_values()
print (coef)
coef.plot(kind='bar', title="Model Coefficients")
plt.show()
# Out:
# Train Test Split
# (8523, 22) (8523,)
# (5966, 22) (2557, 22) (5966,) (2557,)
# Model Report
# Scoring - neg_mean_squared_error
# [-0.29362336 -0.29855725 -0.2848808  -0.28841046 -0.28022464]
# ABS Average of - neg_mean_squared_error 0.28913930069905824
#
# R2 Score
# [0.72122305 0.7106351  0.70746092 0.71541618 0.74010375]
# Average R2 Score  0.7189677985439288
#
# Accuracy
# Accuracy of Test data
# R2_Score: 0.7136391970550767
# Accuracy of Training data
# R2_Score: 0.7232624990443841
# Accuracy of Complete data
# R2_Score: 0.7203110558484953
#
# Display actual and predicted values
# Outlet_Type_0            -1.254723
# Outlet_Size_1            -0.735141
# Outlet_Size_2            -0.575278
# Outlet_Type_1            -0.476526
# Outlet_Location_Type_2   -0.383803
# Outlet_Type_2            -0.293352
# Outlet_Years             -0.073229
# Item_Visibility          -0.038618
# New_Item_Type_0          -0.026509
# Item_Fat_Content_0       -0.010449
# Item_Weight              -0.001516
# Item_Type                 0.000923
# Item_Fat_Content_2        0.005071
# Item_Fat_Content_1        0.005377
# New_Item_Type_2           0.005377
# Item_MRP                  0.008172
# New_Item_Type_1           0.021131
# Outlet_Location_Type_1    0.030356
# Outlet                    0.061955
# Outlet_Location_Type_0    0.353446
# Outlet_Size_0             1.310419
# Outlet_Type_3             2.024600
# dtype: float64

# %%
from sklearn.linear_model import Ridge
model = Ridge()
train(model, X,y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
plt.show()
# Out:
# Train Test Split
# (8523, 22) (8523,)
# (5966, 22) (2557, 22) (5966,) (2557,)
# Model Report
# Scoring - neg_mean_squared_error
# [-0.2931799  -0.29900886 -0.28516812 -0.28877548 -0.28047642]
# ABS Average of - neg_mean_squared_error 0.28932175794002457
#
# R2 Score
# [0.72164409 0.71019739 0.70716587 0.715056   0.73987023]
# Average R2 Score  0.7187867146748422
#
# Accuracy
# Accuracy of Test data
# R2_Score: 0.7132086988032391
# Accuracy of Training data
# R2_Score: 0.7230806625087238
# Accuracy of Complete data
# R2_Score: 0.7200528916859525
#
# Display actual and predicted values

# %%
from sklearn.linear_model import Lasso
model = Lasso()
train(model, X,y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
plt.show()
# Out:
# Train Test Split
# (8523, 22) (8523,)
# (5966, 22) (2557, 22) (5966,) (2557,)
# Model Report
# Scoring - neg_mean_squared_error
# [-0.76444141 -0.75797033 -0.72014686 -0.75959604 -0.81323995]
# ABS Average of - neg_mean_squared_error 0.7630789166281843
#
# R2 Score
# [0.27421086 0.26536699 0.26049386 0.2504823  0.24575506]
# Average R2 Score  0.2592618151206076
#
# Accuracy
# Accuracy of Test data
# R2_Score: 0.2538352830427828
# Accuracy of Training data
# R2_Score: 0.26227683517122646
# Accuracy of Complete data
# R2_Score: 0.2596923551013074
#
# Display actual and predicted values

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
train(model, X,y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
plt.show()
# Out:
# Train Test Split
# (8523, 22) (8523,)
# (5966, 22) (2557, 22) (5966,) (2557,)
# Model Report
# Scoring - neg_mean_squared_error
# [-0.57891131 -0.58803885 -0.57125384 -0.59895109 -0.53462332]
# ABS Average of - neg_mean_squared_error 0.57435568407329
#
# R2 Score
# [0.45658672 0.42566735 0.41867645 0.38428026 0.49500329]
# Average R2 Score  0.43604281238507125
#
# Accuracy
# Accuracy of Test data
# R2_Score: 0.4538944134613445
# Accuracy of Training data
# R2_Score: 1.0
# Accuracy of Complete data
# R2_Score: 0.8323672354128737
#
# Display actual and predicted values

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
train(model, X,y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
plt.show()
# Out:
# Train Test Split
# (8523, 22) (8523,)
# (5966, 22) (2557, 22) (5966,) (2557,)
# Model Report
# Scoring - neg_mean_squared_error
# [-0.31485501 -0.32142957 -0.30042226 -0.31716129 -0.29892687]
# ABS Average of - neg_mean_squared_error 0.3105589985888185
#
# R2 Score
# [0.70341821 0.68723303 0.69437647 0.69112695 0.72472424]
# Average R2 Score  0.7001757817395716
#
# Accuracy
# Accuracy of Test data
# R2_Score: 0.6946044798849934
# Accuracy of Training data
# R2_Score: 0.9597670315197484
# Accuracy of Complete data
# R2_Score: 0.8783730082710896
#
# Display actual and predicted values

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
train(model, X,y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
plt.show()
# Out:
# Train Test Split
# (8523, 22) (8523,)
# (5966, 22) (2557, 22) (5966,) (2557,)
# Model Report
# Scoring - neg_mean_squared_error
# [-0.33038279 -0.33804743 -0.31923448 -0.33885951 -0.32162084]
# ABS Average of - neg_mean_squared_error 0.32962900974031123
#
# R2 Score
# [0.68433981 0.67306809 0.67243315 0.6696787  0.70077569]
# Average R2 Score  0.6800590872638582
#
# Accuracy
# Accuracy of Test data
# R2_Score: 0.6791960044301352
# Accuracy of Training data
# R2_Score: 1.0
# Accuracy of Complete data
# R2_Score: 0.9015258917074527
#
# Display actual and predicted values

# %%
#verbosity=1 log files won’t be displayed 
from lightgbm import LGBMRegressor
model = LGBMRegressor(verbosity=-1)
train(model, X,y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
plt.show()
# Out:
# Train Test Split
# (8523, 22) (8523,)
# (5966, 22) (2557, 22) (5966,) (2557,)
# Model Report
# Scoring - neg_mean_squared_error
# [-0.28957435 -0.29171368 -0.27528646 -0.28365674 -0.26856312]
# ABS Average of - neg_mean_squared_error 0.2817588697756904
#
# R2 Score
# [0.72506733 0.71726796 0.71731318 0.72010682 0.7509193 ]
# Average R2 Score  0.7261349186439531
#
# Accuracy
# Accuracy of Test data
# R2_Score: 0.7222631749410455
# Accuracy of Training data
# R2_Score: 0.8159406776859842
# Accuracy of Complete data
# R2_Score: 0.7871870802560543
#
# Display actual and predicted values

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
train(model, X,y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
plt.show()
# Out:
# Train Test Split
# (8523, 22) (8523,)
# (5966, 22) (2557, 22) (5966,) (2557,)
# Model Report
# Scoring - neg_mean_squared_error
# [-0.329849   -0.32203594 -0.31545538 -0.32891837 -0.30249742]
# ABS Average of - neg_mean_squared_error 0.31975122045203197
#
# R2 Score
# [0.68682908 0.6878793  0.67606443 0.67544573 0.71944671]
# Average R2 Score  0.6891330466837868
#
# Accuracy
# Accuracy of Test data
# R2_Score: 0.6790166791151621
# Accuracy of Training data
# R2_Score: 0.9120531911594594
# Accuracy of Complete data
# R2_Score: 0.8405210244592273
#
# Display actual and predicted values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
print (X.shape, y.shape)
print (X_train.shape, X_test.shape ,  y_train.shape, y_test.shape)
# Out:
# (8523, 22) (8523,)
# (5966, 22) (2557, 22) (5966,) (2557,)

# %%
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
min_samples_split = [2, 5, 10, 15, 100]
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
from sklearn.model_selection import RandomizedSearchCV
rf = RandomForestRegressor()
rf=RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose= 1, random_state=42, n_jobs = -1)
display (rf.fit(X_train, y_train))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=1)

# %%
print(rf.best_params_)
print(rf.best_score_)

# Display Accuracy
print ()
print ('Accuracy')
print ('Accuracy of Test data')
y_test_pred = rf.predict(X_test)
print('R2_Score:', r2_score(y_test,y_test_pred))
print ('Accuracy of Training data')
y_train_pred = rf.predict(X_train)
print('R2_Score:', r2_score(y_train,y_train_pred))
print ('Accuracy of Complete data')
y_pred = rf.predict(X)
print('R2_Score:', r2_score(y,y_pred))
print ()

# Display graph with actual and predicted values 
    
plt.subplot (212)
print ('Display actual and predicted values')
sns.regplot( x =y, y= y_pred, scatter_kws={"color": "b"}, line_kws={"color": "r"},ci = None)
plt.show()
# Out:
# {'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 20}
# -0.2871573892828564
#
# Accuracy
# Accuracy of Test data
# R2_Score: 0.711103907146125
# Accuracy of Training data
# R2_Score: 0.8272185761492645
# Accuracy of Complete data
# R2_Score: 0.7915775551402828
#
# Display actual and predicted values

# %%
from scipy.stats import uniform, randint
params = {
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.03, 0.3), # default 0.1 
    "max_depth": randint(2, 6), # default 3
    "n_estimators": randint(100, 150), # default 100
    "subsample": uniform(0.6, 0.4)
}

# %%
lgb=LGBMRegressor(verbosity=-1)
lgb = RandomizedSearchCV(estimator = lgb, param_distributions = params,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=1, random_state=42, n_jobs = 1)
lgb.fit(X,y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5, estimator=LGBMRegressor(verbosity=-1), n_jobs=1,
#                    param_distributions={'gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001DC3B8B17F0>,
#                                         'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001DC41576850>,
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001DC3B8B16A0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001DC41577250>,
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001DC415774D0>},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=1)

# %%
print(lgb.best_params_)
print(lgb.best_score_)

# Display Accuracy
print ()
print ('Accuracy')
print ('Accuracy of Test data')
y_test_pred = lgb.predict(X_test)
print('R2_Score:', r2_score(y_test,y_test_pred))
print ('Accuracy of Training data')
y_train_pred = lgb.predict(X_train)
print('R2_Score:', r2_score(y_train,y_train_pred))
print ('Accuracy of Complete data')
y_pred = lgb.predict(X)
print('R2_Score:', r2_score(y,y_pred))
print ()
# Out:
# {'gamma': np.float64(0.22007624686980065), 'learning_rate': np.float64(0.06661147045343364), 'max_depth': 2, 'n_estimators': 107, 'subsample': np.float64(0.6137554084460873)}
# -0.270486817430124
#
# Accuracy
# Accuracy of Test data
# R2_Score: 0.7378840825312187
# Accuracy of Training data
# R2_Score: 0.7474040017170538
# Accuracy of Complete data
# R2_Score: 0.7444840723233541

# %%
plt.subplot (212)
print ('Display actual and predicted values')
sns.regplot( x =y, y= y_pred, scatter_kws={"color": "b"}, line_kws={"color": "r"},ci = None)
plt.show()
# Out:
# Display actual and predicted values

# %%
params = {
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.03, 0.3), # default 0.1 
    "max_depth": randint(2, 6), # default 3
    "n_estimators": randint(100, 150), # default 100
    "subsample": uniform(0.6, 0.4)
}

# %%
from xgboost import XGBRegressor
model = XGBRegressor()
xgb = RandomizedSearchCV(estimator = model, param_distributions = params,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=1, random_state=42, n_jobs = 1)
xgb.fit(X,y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           feature_weights=None, gamma=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraint...
#                                         'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001DC3B8A5CD0>,
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001DC415E1A90>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001DC3B8A6EA0>,
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001DC3CDE05F0>},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=1)

# %%
print(xgb.best_params_)
print(xgb.best_score_)

# Display Accuracy
print ()
print ('Accuracy')
print ('Accuracy of Test data')
y_test_pred = xgb.predict(X_test)
print('R2_Score:', r2_score(y_test,y_test_pred))
print ('Accuracy of Training data')
y_train_pred = xgb.predict(X_train)
print('R2_Score:', r2_score(y_train,y_train_pred))
print ('Accuracy of Complete data')
y_pred = xgb.predict(X)
print('R2_Score:', r2_score(y,y_pred))
print ()

# Display graph with actual and predicted values 
    
plt.subplot (212)
print ('Display actual and predicted values')
sns.regplot( x =y, y= y_pred, scatter_kws={"color": "b"}, line_kws={"color": "r"},ci = None)
plt.show()
# Out:
# {'gamma': np.float64(0.22007624686980065), 'learning_rate': np.float64(0.06661147045343364), 'max_depth': 2, 'n_estimators': 107, 'subsample': np.float64(0.6137554084460873)}
# -0.26952485754391303
#
# Accuracy
# Accuracy of Test data
# R2_Score: 0.7391790685107
# Accuracy of Training data
# R2_Score: 0.7472033016777186
# Accuracy of Complete data
# R2_Score: 0.744742490429103
#
# Display actual and predicted values
